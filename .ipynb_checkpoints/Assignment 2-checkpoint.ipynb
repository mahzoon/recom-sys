# %% [markdown]
# # Assignment 2: Content-based Filtering

# %% [markdown]
# ## Reading Data

# %%
import pandas as pd
import numpy as np

# %%
tags = pd.read_csv('data/movie-tags.csv', header=None, names=['movie_id', 'tag'])
movies = pd.read_csv('data/movie-titles.csv', header=None, names=['movie_id', 'movie', 'genres'])
ratings = pd.read_csv('data/ratings.csv', header=None, names=['user_id', 'movie_id', 'rating'])

# %% [markdown]
# ## Part 1: TF-IDF Recommender with Unweighted Profiles

# %% [markdown]
# ### Compute item-tag vectors (the model)

# %% [markdown]
# Step 1: Iterate through items, building the term vector 𝒒𝑖 for each item and a global document frequency vector 𝒅. At this stage, these are unnormalized term and document frequency vectors, storing the number of times the term appears on each document or the number of documents in which it appears.

# %% [markdown]
# * first initializing item_tag_dict

# %%
item_tag_dict = {}
for movie in movies['movie_id'].tolist():
    item_tag_dict[movie] = {}

# %% [markdown]
# * then, filling item_tag_dict

# %%
item_tags = tags.groupby('movie_id')
for item in item_tags:
    item_i_tags = item[1]['tag'].value_counts().to_dict()
    item_tag_dict[item[0]] = item_i_tags
Q = pd.DataFrame.from_dict(item_tag_dict, orient='index')

# %% [markdown]
# * also, we need to put items with no tag count in Q, and sort it based on item_id

# %%
item_with_no_tags = [i for i in item_tag_dict.keys() if len(item_tag_dict[i]) == 0]
for item in item_with_no_tags:
    Q.loc[item] = np.nan
Q = Q.sort_index()

# %% [markdown]
# Step 2: Iterate through each item again, performing the following:<br />
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;a. Divide each term value 𝑞̂𝑖𝑡 by the log of the document frequency (𝑙𝑛 𝑑𝑡). The resulting
# vector 𝒒𝑖 is the TF-IDF vector.

# %%
Q = Q.fillna(0)
df = Q.count()
idf = np.log(df)
Q = Q/idf

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;b. After dividing each term value by the log of the DF, compute the length (Euclidean norm) of the TF-IDF vector 𝒒𝑖, and divide each element of it by the length to yield a unit vector 𝒒𝑖.

# %%
Q = Q.div(np.sqrt(np.square(Q).sum(axis=1)), axis=0)
Q = Q.fillna(0)

# %% [markdown]
# ### Build user profile for each query user

# %% [markdown]
# The profile is the sum of the item-tag vectors of all items the user has rated positively (>= 3.5 stars)

# %% [markdown]
# $$ p_{ut} = \sum_{i\in{I},\, r_{ui} \geq{3.5}}{q_{it}} $$

# %% [markdown]
# * first building the user rating matrix (movies * users)

# %%
item_rating_dict = {}
item_ratings = ratings.groupby('movie_id')
for item in item_ratings:
    item_i_ratings = item[1][['user_id','rating']].set_index('user_id').to_dict()['rating']
    item_rating_dict[item[0]] = item_i_ratings
R = pd.DataFrame.from_dict(item_rating_dict, orient='index')
R = R.sort_index()
R = R.T

# %% [markdown]
# * then, converting ratings to 1 if ratings>=3.5 otherwise 0

# %%
R35 = R.copy()
R35[R35<3.5]=0
R35[R35>=3.5]=1
R35 = R35.fillna(0)

# %% [markdown]
# * finally, doing the dot product

# %%
P = R35.dot(Q)

# %% [markdown]
# ### Generate item scores for each user

# %% [markdown]
# The score for an item is the cosine between that item’s tag vector and the user’s profile vector.<br />
# Cosine similarity is defined as follows:

# %% [markdown]
# $$ \cos{(p_{u},\,q_{i})} = \frac{p_{u} \cdot q_{i}}{\parallel p_{u} \parallel_{2} \parallel q_{i} \parallel_{2}} = \frac{\sum_{t}{q_{ut}p_{ut}}}{\sqrt{\sum_{t}{q_{ut}^2}}\sqrt{\sum_{t}{p_{ut}^2}}} $$

# %%
from scipy.spatial.distance import cdist

# %% [markdown]
# * pairwise 'cosine' distance

# %%
c = cdist(P.values, Q.values, 'cosine')

# %% [markdown]
# * cosine similarity score matrix (user * item)

# %%
S = pd.DataFrame(1 - c, index=P.index, columns=Q.index)

# %% [markdown]
# ## Part 2: Weighted User Profile

# %% [markdown]
# In this variant, rather than just summing the vectors for all positively-rated items, compute a weighted sum of the item vectors for all rated items, with weights being based on the user’s rating:

# %% [markdown]
# $$ p_{u} = \sum_{i\in{I(u)}}{ (r_{ui} - \mu_{u}) \cdot q_{i} } $$

# %%
RW = R.copy()
mu = RW.mean(axis=1)
W = RW.sub(s, axis=0)
W = W.fillna(0)

# %%
PW = W.dot(Q)

# %%
PW
# Out:
#           family    classic  humorous   fantasy    bright  fanciful      toys  \
# 12288   0.680782   2.239962  0.889096  5.076983 -0.190889  0.401534  0.104936
# 71680   0.915897   2.721329 -0.317350 -2.257227  0.046179  0.009585  0.024708
# 32780  -2.389675  11.561317  1.349053  2.374417 -0.552643 -0.052796 -0.008220
# 106512  0.320252   5.650538  0.767279  0.084404  0.065380  0.352630 -0.070522
# 32785   0.335856   2.114862 -0.751138 -3.016836  0.024910  0.192757  0.099642
# 67615   0.412273   1.047495  0.273987  0.534646  0.067169  0.029938  0.360142
# 59424   0.793354   0.113296 -0.710635  1.758995  0.034288  0.144044  0.124346
# 96296   0.263022  -0.311171  0.347092  0.041191  0.031587 -0.106285 -0.126373
# 106537 -0.385471  -0.259102  0.125696  1.947083  0.051618  0.271443  0.112651
# 57387   0.032051   1.277970  0.211503 -0.845837  0.037970  0.025043  0.033007
# 38957   1.014379   3.102946  0.142301  1.291661 -0.054084  0.101823 -0.184665
# 47150  -0.137610  -0.801852 -0.385811  0.611905  0.212757  0.397232  0.303865
# 20530   0.578715   2.773178 -0.182872 -0.216013  0.127689  0.336400  0.327810
# 102750 -1.344543   0.477915 -0.167846  0.314474  0.035433  0.019139 -0.050523
# 129078 -0.334990   5.175728  0.641086  0.001236  0.085750  0.322902  0.604701
# 104508 -0.320043   1.466429 -0.036804  1.120982 -0.302938  0.081798  0.090336
# 63551  -0.000401   0.825078 -0.399835  1.206116  0.027752  0.092914 -0.022349
# 96320   0.106962   1.459339  0.010591  0.292292  0.094736  0.258339  0.134005
# 124998  0.760982   7.459156  1.370549  5.261194  0.097166  1.052409  0.176580
# 112736  0.139293   0.363774 -0.024975 -0.267585  0.012282  0.012282  0.049126
# 14437   0.005820   3.528142  0.340338  1.901085 -0.078293  0.110993  0.008578
# 90216   0.372612   0.772460  0.029898 -0.384009 -0.050077  0.066179  0.092665
# 359     0.895365   7.430051 -0.066993  1.818018  0.066612  0.318989  0.468697
# 120941 -0.179329  -0.145481  0.116129 -2.599028 -0.010181 -0.151340  0.223126
# 65648   0.089555   0.134293  0.023634  0.323964  0.024303  0.057598  0.097210
# 96370  -0.947930   8.735331  2.177640  2.929975  0.423490  0.576447  0.365963
# 4215    1.172732   3.054415  0.153830 -1.192928  0.139138  0.215861  0.398699
# 63615   0.057889   0.570184  0.425619  0.456724  0.037831  0.261774 -0.156027
# 60971  -0.812678   0.328425  0.125014 -0.038521  0.021749  0.055869  0.297304
# 102532  0.535958   6.734530  2.843067  2.333457  0.196774  0.243784  0.274111
# ...          ...        ...       ...       ...       ...       ...       ...
# 69374   0.245940   0.214087 -0.124101 -0.694190  0.000000 -0.133125  0.000000
# 27142   0.000000  -0.040131 -0.107466  0.257145 -0.013792  0.000000  0.000000
# 45854   0.063116   0.811978 -0.034533  0.146132 -0.033181 -0.022730  0.000000
# 93203   0.024678   0.126956  0.168805  1.190169  0.000000  0.146942  0.000000
# 66756   0.036809  -0.508884 -0.170272 -0.349752  0.000000  0.000000  0.000000
# 126292 -0.126156   0.499383 -0.017911  0.154804  0.000000  0.089085  0.000000
# 109970 -0.230965  -0.455000  0.517844  1.943883  0.000000 -0.187963  0.000000
# 97436  -0.116119  -0.295009  0.131559  0.000000  0.000000  0.000000  0.000000
# 12014   0.345041   1.138986 -0.494074  0.132550 -0.199265 -0.298542 -0.199265
# 111036  0.000000   0.477198  0.000000 -0.704394  0.000000  0.000000  0.000000
# 104529  0.053318   0.478780 -0.110130  0.182157  0.000000 -0.048245  0.000000
# 127647  0.007059   0.142867  0.209642  1.880344  0.037306  0.176859  0.000000
# 124981  0.000000   0.641789  0.036646  0.000000  0.000000  0.000000  0.000000
# 121403  0.000000   0.141902  0.026233  0.005459  0.015314  0.000000  0.000000
# 17194   0.000000   0.544392  0.101543  0.137965  0.000000  0.041392  0.000000
# 18204  -1.877281   0.081580  0.096779  0.728395  0.000000  0.054960  0.000000
# 12255   0.000000   0.221216  0.336143  0.077776  0.000000  0.161249  0.000000
# 119134  0.196744   0.636841  0.000000  2.078133  0.000000  0.104727 -0.402192
# 8335    0.000000   0.256911  0.004985 -0.034904  0.000000  0.000000  0.000000
# 56478   0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 49806   0.000000  -0.086110  0.000000 -0.124189  0.000000  0.000000  0.000000
# 128079  0.000000  -0.021569  0.175927  0.312730  0.000000  0.000000  0.000000
# 53819   0.000000   1.029314  0.000000 -0.159693  0.000000  0.000000  0.000000
# 72633   0.005847  -0.019917 -0.104863  1.212595 -0.006266 -0.165328 -0.006266
# 43116   0.004146   0.165883  0.334468  0.110758  0.000000  0.022656  0.000000
# 26008  -0.049630   0.191534  0.124611 -2.504115  0.051640 -0.099259  0.000000
# 81574   0.000000   0.495657  0.000000  1.067488  0.000000  0.000000  0.000000
# 86309   0.044803   0.020007 -0.005383  0.933728  0.000000  0.049594  0.000000
# 84598   0.077239   0.050229 -0.081606 -0.070634  0.000000  0.045256  0.000000
# 44194   0.023247  -0.435576 -0.082061  1.224596  0.000000  0.056727  0.000000
#
#         computer animation  children    Disney        ...          \
# 12288             0.236688 -0.478862 -0.107620        ...
# 71680            -0.094119 -0.000065 -0.564032        ...
# 32780             0.057267 -0.843788 -2.976817        ...
# 106512           -0.026553 -0.174474  0.657810        ...
# 32785             0.049821  0.234333  0.971619        ...
# 67615             0.030958  0.528448  1.848851        ...
# 59424             0.021605  0.216026 -2.261039        ...
# 96296            -0.238287 -0.114265 -0.455689        ...
# 106537            0.073034 -0.015353 -3.210425        ...
# 57387             0.304464  0.055075 -0.369609        ...
# 38957            -0.057379 -0.393482  2.842239        ...
# 47150             0.128618  0.291200 -1.886296        ...
# 20530             0.041828 -0.082366 -1.248959        ...
# 102750           -0.148028 -0.423454 -0.085636        ...
# 129078            0.049711  0.209887  0.173692        ...
# 104508            0.412377 -0.061113 -3.322561        ...
# 63551             0.234506 -0.036043 -0.171684        ...
# 96320             0.046447  0.156404 -1.225400        ...
# 124998            0.458458  0.849981 -0.491150        ...
# 112736            0.098339  0.101420  0.631586        ...
# 14437             0.001912 -0.417975 -0.767540        ...
# 90216             0.068039 -0.101368  0.756875        ...
# 359               0.313701  0.635457  4.015296        ...
# 120941           -0.230275 -0.303685  0.061563        ...
# 65648             0.048605  0.037961  0.096645        ...
# 96370             0.136713  0.623861 -2.961389        ...
# 4215              0.211841 -0.363931  1.160229        ...
# 63615            -0.322003 -0.332625  0.288804        ...
# 60971             0.067448  0.112007  0.101674        ...
# 102532           -0.200357  0.022329  2.780626        ...
# ...                    ...       ...       ...        ...
# 69374             0.000000  0.000000  0.000000        ...
# 27142             0.006962  0.000000  0.000000        ...
# 45854            -0.015491 -0.072689 -1.383878        ...
# 93203             0.000000  0.000000 -0.114274        ...
# 66756             0.371340  0.175042  0.058624        ...
# 126292           -0.018330  0.000000 -0.018330        ...
# 109970            0.195540  0.272578  2.118933        ...
# 97436            -0.104765  0.000000 -0.104765        ...
# 12014            -0.199265  0.098504 -1.752682        ...
# 111036            0.000000  0.000000  0.000000        ...
# 104529            0.000000  0.108810  0.100826        ...
# 127647            0.000000  0.022753  0.000000        ...
# 124981            0.189129  0.007165  0.391534        ...
# 121403            0.000000  0.000000  0.000000        ...
# 17194             0.000000  0.000000  0.000000        ...
# 18204            -0.415393 -0.070592  0.122463        ...
# 12255             0.006962 -0.248584  0.077776        ...
# 119134           -0.016229 -0.232207 -0.272687        ...
# 8335              0.000000  0.000000  0.000000        ...
# 56478             0.000000  0.000000  0.000000        ...
# 49806             0.070401 -0.046389 -0.659864        ...
# 128079            0.000000  0.000000  0.000000        ...
# 53819             0.000000  0.000000  0.000000        ...
# 72633            -0.006266  0.000000 -0.213325        ...
# 43116             0.000000  0.008292 -0.160450        ...
# 26008            -0.162447  0.000000  0.000000        ...
# 81574             0.049625  0.000000  0.429418        ...
# 86309             0.000000  0.040013  0.000000        ...
# 84598             0.000000  0.000000  0.000000        ...
# 44194             0.000000  0.000000  0.000000        ...
#
#         abomination  Evangeline Lilly  not enough Bilbo    hobbit  \
# 12288      0.000000          0.000000          0.000000  0.000000
# 71680      0.000000          0.000000          0.000000  0.000000
# 32780      0.000000          0.000000          0.000000  0.000000
# 106512     0.000000          0.000000          0.000000  0.000000
# 32785      0.000000          0.000000          0.000000  0.000000
# 67615      0.000000          0.000000          0.000000  0.000000
# 59424      0.000000          0.000000          0.000000  0.000000
# 96296      0.000000          0.000000          0.000000  0.000000
# 106537    -0.081757         -0.163514         -0.081757 -0.081757
# 57387      0.000000          0.000000          0.000000  0.000000
# 38957      0.000000          0.000000          0.000000  0.000000
# 47150      0.000000          0.000000          0.000000  0.000000
# 20530      0.000000          0.000000          0.000000  0.000000
# 102750     0.000000          0.000000          0.000000  0.000000
# 129078     0.000000          0.000000          0.000000  0.000000
# 104508     0.000000          0.000000          0.000000  0.000000
# 63551      0.146368          0.292736          0.146368  0.146368
# 96320      0.000000          0.000000          0.000000  0.000000
# 124998    -0.003839         -0.007677         -0.003839 -0.003839
# 112736     0.000000          0.000000          0.000000  0.000000
# 14437      0.000000          0.000000          0.000000  0.000000
# 90216      0.000000          0.000000          0.000000  0.000000
# 359        0.000000          0.000000          0.000000  0.000000
# 120941     0.000000          0.000000          0.000000  0.000000
# 65648      0.000000          0.000000          0.000000  0.000000
# 96370      0.000000          0.000000          0.000000  0.000000
# 4215       0.000000          0.000000          0.000000  0.000000
# 63615      0.000000          0.000000          0.000000  0.000000
# 60971      0.000000          0.000000          0.000000  0.000000
# 102532     0.000000          0.000000          0.000000  0.000000
# ...             ...               ...               ...       ...
# 69374      0.000000          0.000000          0.000000  0.000000
# 27142      0.000000          0.000000          0.000000  0.000000
# 45854      0.000000          0.000000          0.000000  0.000000
# 93203      0.000000          0.000000          0.000000  0.000000
# 66756      0.000000          0.000000          0.000000  0.000000
# 126292     0.000000          0.000000          0.000000  0.000000
# 109970     0.000000          0.000000          0.000000  0.000000
# 97436      0.000000          0.000000          0.000000  0.000000
# 12014      0.000000          0.000000          0.000000  0.000000
# 111036     0.000000          0.000000          0.000000  0.000000
# 104529     0.000000          0.000000          0.000000  0.000000
# 127647     0.000000          0.000000          0.000000  0.000000
# 124981     0.000000          0.000000          0.000000  0.000000
# 121403     0.000000          0.000000          0.000000  0.000000
# 17194      0.000000          0.000000          0.000000  0.000000
# 18204      0.000000          0.000000          0.000000  0.000000
# 12255      0.000000          0.000000          0.000000  0.000000
# 119134     0.000000          0.000000          0.000000  0.000000
# 8335       0.000000          0.000000          0.000000  0.000000
# 56478      0.000000          0.000000          0.000000  0.000000
# 49806      0.000000          0.000000          0.000000  0.000000
# 128079     0.000000          0.000000          0.000000  0.000000
# 53819      0.000000          0.000000          0.000000  0.000000
# 72633      0.000000          0.000000          0.000000  0.000000
# 43116      0.000000          0.000000          0.000000  0.000000
# 26008      0.000000          0.000000          0.000000  0.000000
# 81574      0.000000          0.000000          0.000000  0.000000
# 86309      0.000000          0.000000          0.000000  0.000000
# 84598      0.000000          0.000000          0.000000  0.000000
# 44194      0.000000          0.000000          0.000000  0.000000
#
#         lousy camerawork/cinematography  alcoholic     messy  \
# 12288                          0.000000   0.000000  0.000000
# 71680                          0.000000   0.000000  0.000000
# 32780                          0.000000   0.000000  0.000000
# 106512                         0.000000   0.000000  0.000000
# 32785                          0.000000   0.000000  0.000000
# 67615                          0.000000   0.000000  0.000000
# 59424                          0.000000   0.000000  0.000000
# 96296                         -0.016512  -0.066048 -0.016512
# 106537                         0.000000   0.000000  0.000000
# 57387                          0.000000   0.000000  0.000000
# 38957                         -0.047289  -0.189157 -0.047289
# 47150                          0.000000   0.000000  0.000000
# 20530                          0.000000   0.000000  0.000000
# 102750                         0.000000   0.000000  0.000000
# 129078                         0.000000   0.000000  0.000000
# 104508                         0.000000   0.000000  0.000000
# 63551                          0.000000   0.000000  0.000000
# 96320                          0.000000   0.000000  0.000000
# 124998                        -0.091219  -0.364877 -0.091219
# 112736                         0.000000   0.000000  0.000000
# 14437                          0.000000   0.000000  0.000000
# 90216                          0.002937   0.011748  0.002937
# 359                            0.018830   0.075321  0.018830
# 120941                         0.000000   0.000000  0.000000
# 65648                          0.000000   0.000000  0.000000
# 96370                          0.000000   0.000000  0.000000
# 4215                           0.000000   0.000000  0.000000
# 63615                          0.058243   0.232972  0.058243
# 60971                          0.000000   0.000000  0.000000
# 102532                        -0.027926  -0.111704 -0.027926
# ...                                 ...        ...       ...
# 69374                          0.000000   0.000000  0.000000
# 27142                          0.000000   0.000000  0.000000
# 45854                          0.000000   0.000000  0.000000
# 93203                          0.000000   0.000000  0.000000
# 66756                          0.000000   0.000000  0.000000
# 126292                         0.000000   0.000000  0.000000
# 109970                         0.000000   0.000000  0.000000
# 97436                          0.000000   0.000000  0.000000
# 12014                          0.000000   0.000000  0.000000
# 111036                         0.000000   0.000000  0.000000
# 104529                         0.000000   0.000000  0.000000
# 127647                         0.000000   0.000000  0.000000
# 124981                         0.000000   0.000000  0.000000
# 121403                         0.000000   0.000000  0.000000
# 17194                          0.000000   0.000000  0.000000
# 18204                          0.000000   0.000000  0.000000
# 12255                          0.000000   0.000000  0.000000
# 119134                         0.000000   0.000000  0.000000
# 8335                           0.000000   0.000000  0.000000
# 56478                          0.000000   0.000000  0.000000
# 49806                          0.000000   0.000000  0.000000
# 128079                         0.000000   0.000000  0.000000
# 53819                          0.000000   0.000000  0.000000
# 72633                          0.000000   0.000000  0.000000
# 43116                          0.000000   0.000000  0.000000
# 26008                          0.000000   0.000000  0.000000
# 81574                          0.000000   0.000000  0.000000
# 86309                          0.000000   0.000000  0.000000
# 84598                          0.000000   0.000000  0.000000
# 44194                          0.000000   0.000000  0.000000
#
#         apprenticeship/training of an adult  political metaphor  \
# 12288                              0.000000            0.000000
# 71680                              0.000000            0.000000
# 32780                              0.000000            0.000000
# 106512                             0.000000            0.000000
# 32785                              0.000000            0.000000
# 67615                              0.000000            0.000000
# 59424                              0.000000            0.000000
# 96296                             -0.016512           -0.016512
# 106537                             0.000000            0.000000
# 57387                              0.000000            0.000000
# 38957                             -0.047289           -0.047289
# 47150                              0.000000            0.000000
# 20530                              0.000000            0.000000
# 102750                             0.000000            0.000000
# 129078                             0.000000            0.000000
# 104508                             0.000000            0.000000
# 63551                              0.000000            0.000000
# 96320                              0.000000            0.000000
# 124998                            -0.091219           -0.091219
# 112736                             0.000000            0.000000
# 14437                              0.000000            0.000000
# 90216                              0.002937            0.002937
# 359                                0.018830            0.018830
# 120941                             0.000000            0.000000
# 65648                              0.000000            0.000000
# 96370                              0.000000            0.000000
# 4215                               0.000000            0.000000
# 63615                              0.058243            0.058243
# 60971                              0.000000            0.000000
# 102532                            -0.027926           -0.027926
# ...                                     ...                 ...
# 69374                              0.000000            0.000000
# 27142                              0.000000            0.000000
# 45854                              0.000000            0.000000
# 93203                              0.000000            0.000000
# 66756                              0.000000            0.000000
# 126292                             0.000000            0.000000
# 109970                             0.000000            0.000000
# 97436                              0.000000            0.000000
# 12014                              0.000000            0.000000
# 111036                             0.000000            0.000000
# 104529                             0.000000            0.000000
# 127647                             0.000000            0.000000
# 124981                             0.000000            0.000000
# 121403                             0.000000            0.000000
# 17194                              0.000000            0.000000
# 18204                              0.000000            0.000000
# 12255                              0.000000            0.000000
# 119134                             0.000000            0.000000
# 8335                               0.000000            0.000000
# 56478                              0.000000            0.000000
# 49806                              0.000000            0.000000
# 128079                             0.000000            0.000000
# 53819                              0.000000            0.000000
# 72633                              0.000000            0.000000
# 43116                              0.000000            0.000000
# 26008                              0.000000            0.000000
# 81574                              0.000000            0.000000
# 86309                              0.000000            0.000000
# 84598                              0.000000            0.000000
# 44194                              0.000000            0.000000
#
#         derailed by twist
# 12288            0.000000
# 71680            0.000000
# 32780            0.000000
# 106512           0.000000
# 32785            0.000000
# 67615            0.000000
# 59424            0.000000
# 96296           -0.016512
# 106537           0.000000
# 57387            0.000000
# 38957           -0.047289
# 47150            0.000000
# 20530            0.000000
# 102750           0.000000
# 129078           0.000000
# 104508           0.000000
# 63551            0.000000
# 96320            0.000000
# 124998          -0.091219
# 112736           0.000000
# 14437            0.000000
# 90216            0.002937
# 359              0.018830
# 120941           0.000000
# 65648            0.000000
# 96370            0.000000
# 4215             0.000000
# 63615            0.058243
# 60971            0.000000
# 102532          -0.027926
# ...                   ...
# 69374            0.000000
# 27142            0.000000
# 45854            0.000000
# 93203            0.000000
# 66756            0.000000
# 126292           0.000000
# 109970           0.000000
# 97436            0.000000
# 12014            0.000000
# 111036           0.000000
# 104529           0.000000
# 127647           0.000000
# 124981           0.000000
# 121403           0.000000
# 17194            0.000000
# 18204            0.000000
# 12255            0.000000
# 119134           0.000000
# 8335             0.000000
# 56478            0.000000
# 49806            0.000000
# 128079           0.000000
# 53819            0.000000
# 72633            0.000000
# 43116            0.000000
# 26008            0.000000
# 81574            0.000000
# 86309            0.000000
# 84598            0.000000
# 44194            0.000000
#
# [862 rows x 13103 columns]
